# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress
from pprint import pprint

response = requests.get("https://api.openbrewerydb.org/breweries?page=402")
data = response.json()
data
# Out:
# [{'id': 7817,
#   'name': 'Capital Brewery Co Inc',
#   'brewery_type': 'regional',
#   'street': '7734 Terrace Ave',
#   'city': 'Middleton',
#   'state': 'Wisconsin',
#   'postal_code': '53562-3163',
#   'country': 'United States',
#   'longitude': '-89.5165797754161',
#   'latitude': '43.09489645',
#   'phone': '6088367100',
#   'website_url': 'http://www.capitalbrewery.com',
#   'updated_at': '2018-08-24T16:42:27.346Z',
#   'tag_list': []},
#  {'id': 7849,
#   'name': 'Funk Factory Geuzeria',
#   'brewery_type': 'micro',
#   'street': '1602 Gilson St',
#   'city': 'Madison',
#   'state': 'Wisconsin',
#   'postal_code': '53715-2128',
#   'country': 'United States',
#   'longitude': '-89.3919797327108',
#   'latitude': '43.0501017743752',
#   'phone': '',
#   'website_url': 'http://www.funkfactorygeuzeria.com',
#   'updated_at': '2018-08-24T16:43:10.601Z',
#   'tag_list': []},
#  {'id': 7858,
#   'name': 'Great Dane Pub and Brewing Co - Fitchburg',
#   'brewery_type': 'brewpub',
#   'street': '2980 Cahill Main',
#   'city': 'Fitchburg',
#   'state': 'Wisconsin',
#   'postal_code': '53711-7146',
#   'country': 'United States',
#   'longitude': '-89.4237090342225',
#   'latitude': '43.0181626711064',
#   'phone': '6084429000',
#   'website_url': 'http://www.greatdanepub.com',
#   'updated_at': '2018-08-24T16:43:22.913Z',
#   'tag_list': []},
#  {'id': 7879,
#   'name': 'Lakefront Brewery Inc',
#   'brewery_type': 'regional',
#   'street': '1872 N Commerce St',
#   'city': 'Milwaukee',
#   'state': 'Wisconsin',
#   'postal_code': '53212-3701',
#   'country': 'United States',
#   'longitude': '-87.9051723',
#   'latitude': '43.0547874',
#   'phone': '4143728800',
#   'website_url': 'http://www.lakefrontbrewery.com',
#   'updated_at': '2018-08-24T16:43:54.449Z',
#   'tag_list': []},
#  {'id': 7895,
#   'name': 'Minhas Craft Brewery',
#   'brewery_type': 'regional',
#   'street': '1208 14th Ave',
#   'city': 'Monroe',
#   'state': 'Wisconsin',
#   'postal_code': '53566-2055',
#   'country': 'United States',
#   'longitude': '-89.641509',
#   'latitude': '42.5986305132204',
#   'phone': '6083289120',
#   'website_url': 'http://www.minhasbrewery.com',
#   'updated_at': '2018-08-24T16:44:17.355Z',
#   'tag_list': []},
#  {'id': 7899,
#   'name': 'MoonRidge Brewpub',
#   'brewery_type': 'brewpub',
#   'street': '501 Bridge St',
#   'city': 'Cornell',
#   'state': 'Wisconsin',
#   'postal_code': '54732-8392',
#   'country': 'United States',
#   'longitude': '-91.1589648',
#   'latitude': '45.1653752',
#   'phone': '7152391341',
#   'website_url': 'http://www.facebook.com/MoonRidge-Brew-Pub-1501996800095070',
#   'updated_at': '2018-08-24T16:44:23.532Z',
#   'tag_list': []},
#  {'id': 7905,
#   'name': 'Northwoods Brewpub and Grill',
#   'brewery_type': 'brewpub',
#   'street': '50918 West Street',
#   'city': 'Osseo',
#   'state': 'Wisconsin',
#   'postal_code': '54758',
#   'country': 'United States',
#   'longitude': '-91.2266512323232',
#   'latitude': '44.5827066565657',
#   'phone': '7155520510',
#   'website_url': 'http://www.northwoodsbrewpub.com',
#   'updated_at': '2018-08-24T16:44:31.455Z',
#   'tag_list': []},
#  {'id': 7923,
#   'name': 'Public Craft Brewing Co',
#   'brewery_type': 'micro',
#   'street': '716 58th St',
#   'city': 'Kenosha',
#   'state': 'Wisconsin',
#   'postal_code': '53140-4137',
#   'country': 'United States',
#   'longitude': '-87.8197509130208',
#   'latitude': '42.5831542416945',
#   'phone': '2626522739',
#   'website_url': 'http://www.publiccraftbrewing.com',
#   'updated_at': '2018-08-24T16:44:56.034Z',
#   'tag_list': []},
#  {'id': 7958,
#   'name': 'Stevens Point Brewery',
#   'brewery_type': 'regional',
#   'street': '2617 Water St',
#   'city': 'Stevens Point',
#   'state': 'Wisconsin',
#   'postal_code': '54481-5248',
#   'country': 'United States',
#   'longitude': '-89.5739807755102',
#   'latitude': '44.5102627142857',
#   'phone': '7153449310',
#   'website_url': 'http://www.pointbeer.com',
#   'updated_at': '2018-08-24T16:45:45.320Z',
#   'tag_list': []},
#  {'id': 7973,
#   'name': 'Titletown Brewing Co',
#   'brewery_type': 'brewpub',
#   'street': '200 Dousman St',
#   'city': 'Green Bay',
#   'state': 'Wisconsin',
#   'postal_code': '54303-2712',
#   'country': 'United States',
#   'longitude': '-88.018517',
#   'latitude': '44.51892',
#   'phone': '9204372337',
#   'website_url': 'http://www.titletownbrewing.com',
#   'updated_at': '2018-08-24T16:46:06.736Z',
#   'tag_list': []},
#  {'id': 8000,
#   'name': 'Black Tooth Brewing Co',
#   'brewery_type': 'micro',
#   'street': '312 Broadway St',
#   'city': 'Sheridan',
#   'state': 'Wyoming',
#   'postal_code': '82801-3917',
#   'country': 'United States',
#   'longitude': '-106.953506',
#   'latitude': '44.800895122449',
#   'phone': '3076752337',
#   'website_url': 'http://www.blacktoothbrewingcompany.com',
#   'updated_at': '2018-08-24T16:46:40.667Z',
#   'tag_list': []},
#  {'id': 8007,
#   'name': 'Gillette Brewing Company',
#   'brewery_type': 'brewpub',
#   'street': '301 S Gillette Ave',
#   'city': 'Gillette',
#   'state': 'Wyoming',
#   'postal_code': '82716-3705',
#   'country': 'United States',
#   'longitude': '-105.503614485757',
#   'latitude': '44.29203825',
#   'phone': '3076708948',
#   'website_url': 'http://www.gillettebrewingcompany.com',
#   'updated_at': '2018-08-24T16:46:48.215Z',
#   'tag_list': []}]

# %%
pprint(data[0])
# Out:
# {'brewery_type': 'brewpub',
#  'city': 'Shelby Township',
#  'country': 'United States',
#  'id': 3688,
#  'latitude': '42.6320201428571',
#  'longitude': '-82.9736141428571',
#  'name': 'Sherwood Brewing Co',
#  'phone': '5865329669',
#  'postal_code': '48315-6214',
#  'state': 'Michigan',
#  'street': '45689 Hayes Rd',
#  'tag_list': [],
#  'updated_at': '2018-08-24T00:44:07.869Z',
#  'website_url': 'http://www.sherwoodbrewing.com'}

# %%
for brewery in data[0]:
    pprint(data)
# Out:
# [{'brewery_type': 'brewpub',
#   'city': 'Shelby Township',
#   'country': 'United States',
#   'id': 3688,
#   'latitude': '42.6320201428571',
#   'longitude': '-82.9736141428571',
#   'name': 'Sherwood Brewing Co',
#   'phone': '5865329669',
#   'postal_code': '48315-6214',
#   'state': 'Michigan',
#   'street': '45689 Hayes Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:07.869Z',
#   'website_url': 'http://www.sherwoodbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Saint Clair Shores',
#   'country': 'United States',
#   'id': 3689,
#   'latitude': '42.4712223090048',
#   'longitude': '-82.8887785856805',
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
#   'street': '23836 Smiley Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:18.433Z',
#   'website_url': 'http://www.gulldambrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Lino Lakes',
#   'country': 'United States',
#   'id': 3852,
#   'latitude': '45.1890903',
#   'longitude': '-93.1064135',
#   'name': 'HammerHeart Brewing Company',
#   'phone': '6513482654',
#   'postal_code': '55014-1109',
#   'state': 'Minnesota',
#   'street': '7785 Lake Dr',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:19.341Z',
#   'website_url': 'http://www.hammerheartbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Minneapolis',
#   'country': 'United States',
#   'id': 3875,
#   'latitude': '44.9689387',
#   'longitude': '-93.2794629',
#   'name': 'Lakes & Legends Brewing Company',
#   'phone': '6129996020',
#   'postal_code': '55403-2316',
#   'state': 'Minnesota',
#   'street': '1368 Lasalle Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:28.880Z',
#   'website_url': 'http://www.lakesandlegends.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Burnsville',
#   'country': 'United States',
#   'id': 3894,
#   'latitude': '44.7463634615385',
#   'longitude': '-93.3054737692308',
#   'name': 'Nutmeg Brewhouse',
#   'phone': '9528921438',
#   'postal_code': '55306-6211',
#   'state': 'Minnesota',
#   'street': '1905 County Road 42 W',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.098Z',
#   'website_url': 'http://www.nutmegbrewhouse.com'},
#  {'brewery_type': 'micro',
#   'city': 'Maple Grove',
#   'country': 'United States',
#   'id': 3896,
#   'latitude': '45.1260514285714',
#   'longitude': '-93.4258984285714',
#   'name': 'OMNI Brewing Company',
#   'phone': '7152229832',
#   'postal_code': '55369-3629',
#   'state': 'Minnesota',
#   'street': '9462 Deerwood Ln N',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.980Z',
#   'website_url': ''}]
# [{'brewery_type': 'brewpub',
#   'city': 'Shelby Township',
#   'country': 'United States',
#   'id': 3688,
#   'latitude': '42.6320201428571',
#   'longitude': '-82.9736141428571',
#   'name': 'Sherwood Brewing Co',
#   'phone': '5865329669',
#   'postal_code': '48315-6214',
#   'state': 'Michigan',
#   'street': '45689 Hayes Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:07.869Z',
#   'website_url': 'http://www.sherwoodbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Saint Clair Shores',
#   'country': 'United States',
#   'id': 3689,
#   'latitude': '42.4712223090048',
#   'longitude': '-82.8887785856805',
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
#   'street': '23836 Smiley Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:18.433Z',
#   'website_url': 'http://www.gulldambrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Lino Lakes',
#   'country': 'United States',
#   'id': 3852,
#   'latitude': '45.1890903',
#   'longitude': '-93.1064135',
#   'name': 'HammerHeart Brewing Company',
#   'phone': '6513482654',
#   'postal_code': '55014-1109',
#   'state': 'Minnesota',
#   'street': '7785 Lake Dr',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:19.341Z',
#   'website_url': 'http://www.hammerheartbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Minneapolis',
#   'country': 'United States',
#   'id': 3875,
#   'latitude': '44.9689387',
#   'longitude': '-93.2794629',
#   'name': 'Lakes & Legends Brewing Company',
#   'phone': '6129996020',
#   'postal_code': '55403-2316',
#   'state': 'Minnesota',
#   'street': '1368 Lasalle Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:28.880Z',
#   'website_url': 'http://www.lakesandlegends.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Burnsville',
#   'country': 'United States',
#   'id': 3894,
#   'latitude': '44.7463634615385',
#   'longitude': '-93.3054737692308',
#   'name': 'Nutmeg Brewhouse',
#   'phone': '9528921438',
#   'postal_code': '55306-6211',
#   'state': 'Minnesota',
#   'street': '1905 County Road 42 W',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.098Z',
#   'website_url': 'http://www.nutmegbrewhouse.com'},
#  {'brewery_type': 'micro',
#   'city': 'Maple Grove',
#   'country': 'United States',
#   'id': 3896,
#   'latitude': '45.1260514285714',
#   'longitude': '-93.4258984285714',
#   'name': 'OMNI Brewing Company',
#   'phone': '7152229832',
#   'postal_code': '55369-3629',
#   'state': 'Minnesota',
#   'street': '9462 Deerwood Ln N',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.980Z',
#   'website_url': ''}]
# [{'brewery_type': 'brewpub',
#   'city': 'Shelby Township',
#   'country': 'United States',
#   'id': 3688,
#   'latitude': '42.6320201428571',
#   'longitude': '-82.9736141428571',
#   'name': 'Sherwood Brewing Co',
#   'phone': '5865329669',
#   'postal_code': '48315-6214',
#   'state': 'Michigan',
#   'street': '45689 Hayes Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:07.869Z',
#   'website_url': 'http://www.sherwoodbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Saint Clair Shores',
#   'country': 'United States',
#   'id': 3689,
#   'latitude': '42.4712223090048',
#   'longitude': '-82.8887785856805',
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
#   'street': '23836 Smiley Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:18.433Z',
#   'website_url': 'http://www.gulldambrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Lino Lakes',
#   'country': 'United States',
#   'id': 3852,
#   'latitude': '45.1890903',
#   'longitude': '-93.1064135',
#   'name': 'HammerHeart Brewing Company',
#   'phone': '6513482654',
#   'postal_code': '55014-1109',
#   'state': 'Minnesota',
#   'street': '7785 Lake Dr',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:19.341Z',
#   'website_url': 'http://www.hammerheartbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Minneapolis',
#   'country': 'United States',
#   'id': 3875,
#   'latitude': '44.9689387',
#   'longitude': '-93.2794629',
#   'name': 'Lakes & Legends Brewing Company',
#   'phone': '6129996020',
#   'postal_code': '55403-2316',
#   'state': 'Minnesota',
#   'street': '1368 Lasalle Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:28.880Z',
#   'website_url': 'http://www.lakesandlegends.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Burnsville',
#   'country': 'United States',
#   'id': 3894,
#   'latitude': '44.7463634615385',
#   'longitude': '-93.3054737692308',
#   'name': 'Nutmeg Brewhouse',
#   'phone': '9528921438',
#   'postal_code': '55306-6211',
#   'state': 'Minnesota',
#   'street': '1905 County Road 42 W',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.098Z',
#   'website_url': 'http://www.nutmegbrewhouse.com'},
#  {'brewery_type': 'micro',
#   'city': 'Maple Grove',
#   'country': 'United States',
#   'id': 3896,
#   'latitude': '45.1260514285714',
#   'longitude': '-93.4258984285714',
#   'name': 'OMNI Brewing Company',
#   'phone': '7152229832',
#   'postal_code': '55369-3629',
#   'state': 'Minnesota',
#   'street': '9462 Deerwood Ln N',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.980Z',
#   'website_url': ''}]
# [{'brewery_type': 'brewpub',
#   'city': 'Shelby Township',
#   'country': 'United States',
#   'id': 3688,
#   'latitude': '42.6320201428571',
#   'longitude': '-82.9736141428571',
#   'name': 'Sherwood Brewing Co',
#   'phone': '5865329669',
#   'postal_code': '48315-6214',
#   'state': 'Michigan',
#   'street': '45689 Hayes Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:07.869Z',
#   'website_url': 'http://www.sherwoodbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Saint Clair Shores',
#   'country': 'United States',
#   'id': 3689,
#   'latitude': '42.4712223090048',
#   'longitude': '-82.8887785856805',
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
#   'street': '23836 Smiley Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:18.433Z',
#   'website_url': 'http://www.gulldambrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Lino Lakes',
#   'country': 'United States',
#   'id': 3852,
#   'latitude': '45.1890903',
#   'longitude': '-93.1064135',
#   'name': 'HammerHeart Brewing Company',
#   'phone': '6513482654',
#   'postal_code': '55014-1109',
#   'state': 'Minnesota',
#   'street': '7785 Lake Dr',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:19.341Z',
#   'website_url': 'http://www.hammerheartbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Minneapolis',
#   'country': 'United States',
#   'id': 3875,
#   'latitude': '44.9689387',
#   'longitude': '-93.2794629',
#   'name': 'Lakes & Legends Brewing Company',
#   'phone': '6129996020',
#   'postal_code': '55403-2316',
#   'state': 'Minnesota',
#   'street': '1368 Lasalle Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:28.880Z',
#   'website_url': 'http://www.lakesandlegends.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Burnsville',
#   'country': 'United States',
#   'id': 3894,
#   'latitude': '44.7463634615385',
#   'longitude': '-93.3054737692308',
#   'name': 'Nutmeg Brewhouse',
#   'phone': '9528921438',
#   'postal_code': '55306-6211',
#   'state': 'Minnesota',
#   'street': '1905 County Road 42 W',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.098Z',
#   'website_url': 'http://www.nutmegbrewhouse.com'},
#  {'brewery_type': 'micro',
#   'city': 'Maple Grove',
#   'country': 'United States',
#   'id': 3896,
#   'latitude': '45.1260514285714',
#   'longitude': '-93.4258984285714',
#   'name': 'OMNI Brewing Company',
#   'phone': '7152229832',
#   'postal_code': '55369-3629',
#   'state': 'Minnesota',
#   'street': '9462 Deerwood Ln N',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.980Z',
#   'website_url': ''}]
# [{'brewery_type': 'brewpub',
#   'city': 'Shelby Township',
#   'country': 'United States',
#   'id': 3688,
#   'latitude': '42.6320201428571',
#   'longitude': '-82.9736141428571',
#   'name': 'Sherwood Brewing Co',
#   'phone': '5865329669',
#   'postal_code': '48315-6214',
#   'state': 'Michigan',
#   'street': '45689 Hayes Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:07.869Z',
#   'website_url': 'http://www.sherwoodbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Saint Clair Shores',
#   'country': 'United States',
#   'id': 3689,
#   'latitude': '42.4712223090048',
#   'longitude': '-82.8887785856805',
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
#   'street': '23836 Smiley Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:18.433Z',
#   'website_url': 'http://www.gulldambrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Lino Lakes',
#   'country': 'United States',
#   'id': 3852,
#   'latitude': '45.1890903',
#   'longitude': '-93.1064135',
#   'name': 'HammerHeart Brewing Company',
#   'phone': '6513482654',
#   'postal_code': '55014-1109',
#   'state': 'Minnesota',
#   'street': '7785 Lake Dr',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:19.341Z',
#   'website_url': 'http://www.hammerheartbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Minneapolis',
#   'country': 'United States',
#   'id': 3875,
#   'latitude': '44.9689387',
#   'longitude': '-93.2794629',
#   'name': 'Lakes & Legends Brewing Company',
#   'phone': '6129996020',
#   'postal_code': '55403-2316',
#   'state': 'Minnesota',
#   'street': '1368 Lasalle Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:28.880Z',
#   'website_url': 'http://www.lakesandlegends.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Burnsville',
#   'country': 'United States',
#   'id': 3894,
#   'latitude': '44.7463634615385',
#   'longitude': '-93.3054737692308',
#   'name': 'Nutmeg Brewhouse',
#   'phone': '9528921438',
#   'postal_code': '55306-6211',
#   'state': 'Minnesota',
#   'street': '1905 County Road 42 W',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.098Z',
#   'website_url': 'http://www.nutmegbrewhouse.com'},
#  {'brewery_type': 'micro',
#   'city': 'Maple Grove',
#   'country': 'United States',
#   'id': 3896,
#   'latitude': '45.1260514285714',
#   'longitude': '-93.4258984285714',
#   'name': 'OMNI Brewing Company',
#   'phone': '7152229832',
#   'postal_code': '55369-3629',
#   'state': 'Minnesota',
#   'street': '9462 Deerwood Ln N',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.980Z',
#   'website_url': ''}]
# [{'brewery_type': 'brewpub',
#   'city': 'Shelby Township',
#   'country': 'United States',
#   'id': 3688,
#   'latitude': '42.6320201428571',
#   'longitude': '-82.9736141428571',
#   'name': 'Sherwood Brewing Co',
#   'phone': '5865329669',
#   'postal_code': '48315-6214',
#   'state': 'Michigan',
#   'street': '45689 Hayes Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:07.869Z',
#   'website_url': 'http://www.sherwoodbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Saint Clair Shores',
#   'country': 'United States',
#   'id': 3689,
#   'latitude': '42.4712223090048',
#   'longitude': '-82.8887785856805',
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
# ...
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
#   'street': '23836 Smiley Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:18.433Z',
#   'website_url': 'http://www.gulldambrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Lino Lakes',
#   'country': 'United States',
#   'id': 3852,
#   'latitude': '45.1890903',
#   'longitude': '-93.1064135',
#   'name': 'HammerHeart Brewing Company',
#   'phone': '6513482654',
#   'postal_code': '55014-1109',
#   'state': 'Minnesota',
#   'street': '7785 Lake Dr',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:19.341Z',
#   'website_url': 'http://www.hammerheartbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Minneapolis',
#   'country': 'United States',
#   'id': 3875,
#   'latitude': '44.9689387',
#   'longitude': '-93.2794629',
#   'name': 'Lakes & Legends Brewing Company',
#   'phone': '6129996020',
#   'postal_code': '55403-2316',
#   'state': 'Minnesota',
#   'street': '1368 Lasalle Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:28.880Z',
#   'website_url': 'http://www.lakesandlegends.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Burnsville',
#   'country': 'United States',
#   'id': 3894,
#   'latitude': '44.7463634615385',
#   'longitude': '-93.3054737692308',
#   'name': 'Nutmeg Brewhouse',
#   'phone': '9528921438',
#   'postal_code': '55306-6211',
#   'state': 'Minnesota',
#   'street': '1905 County Road 42 W',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.098Z',
#   'website_url': 'http://www.nutmegbrewhouse.com'},
#  {'brewery_type': 'micro',
#   'city': 'Maple Grove',
#   'country': 'United States',
#   'id': 3896,
#   'latitude': '45.1260514285714',
#   'longitude': '-93.4258984285714',
#   'name': 'OMNI Brewing Company',
#   'phone': '7152229832',
#   'postal_code': '55369-3629',
#   'state': 'Minnesota',
#   'street': '9462 Deerwood Ln N',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.980Z',
#   'website_url': ''}]
# [{'brewery_type': 'brewpub',
#   'city': 'Shelby Township',
#   'country': 'United States',
#   'id': 3688,
#   'latitude': '42.6320201428571',
#   'longitude': '-82.9736141428571',
#   'name': 'Sherwood Brewing Co',
#   'phone': '5865329669',
#   'postal_code': '48315-6214',
#   'state': 'Michigan',
#   'street': '45689 Hayes Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:07.869Z',
#   'website_url': 'http://www.sherwoodbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Saint Clair Shores',
#   'country': 'United States',
#   'id': 3689,
#   'latitude': '42.4712223090048',
#   'longitude': '-82.8887785856805',
#   'name': 'Shipwreck Brewing Company',
#   'phone': '5869442266',
#   'postal_code': '48080-1318',
#   'state': 'Michigan',
#   'street': '24409 Jefferson Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:08.299Z',
#   'website_url': 'http://www.shipwreckbrewingcompany.com'},
#  {'brewery_type': 'micro',
#   'city': 'Bridgman',
#   'country': 'United States',
#   'id': 3710,
#   'latitude': '41.9427559',
#   'longitude': '-86.5561575',
#   'name': 'Tapistry Brewing Company',
#   'phone': '2692667349',
#   'postal_code': '49106-9109',
#   'state': 'Michigan',
#   'street': '4236 Lake St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:18.183Z',
#   'website_url': 'http://www.tapistrybrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Tecumseh',
#   'country': 'United States',
#   'id': 3712,
#   'latitude': '42.004052',
#   'longitude': '-83.946191',
#   'name': 'Tecumseh Brewing Company',
#   'phone': '5178151726',
#   'postal_code': '49286-1553',
#   'state': 'Michigan',
#   'street': '128 W Chicago Blvd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:19.242Z',
#   'website_url': 'http://www.tecumsehbrewingco.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Grand Rapids',
#   'country': 'United States',
#   'id': 3724,
#   'latitude': '42.9850773333333',
#   'longitude': '-85.68101',
#   'name': 'The Mitten Brewing Co',
#   'phone': '6166085612',
#   'postal_code': '49504-4278',
#   'state': 'Michigan',
#   'street': '527 Leonard St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:24.797Z',
#   'website_url': 'http://www.mittenbrewing.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Zeeland',
#   'country': 'United States',
#   'id': 3742,
#   'latitude': '42.81211765',
#   'longitude': '-86.0146348246228',
#   'name': 'Tripelroot',
#   'phone': '6169530050',
#   'postal_code': '49464-1736',
#   'state': 'Michigan',
#   'street': '146 E Main Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:32.320Z',
#   'website_url': 'http://www.tripelroot.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hastings',
#   'country': 'United States',
#   'id': 3755,
#   'latitude': '42.6487487',
#   'longitude': '-85.284584',
#   'name': 'Walldorff Brewpub & Bistro',
#   'phone': '2699454400',
#   'postal_code': '49058-1808',
#   'state': 'Michigan',
#   'street': '105 E State St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:38.945Z',
#   'website_url': 'http://www.walldorffbrewpub.com'},
#  {'brewery_type': 'micro',
#   'city': 'Stevensville',
#   'country': 'United States',
#   'id': 3757,
#   'latitude': '42.0128666818182',
#   'longitude': '-86.51963025',
#   'name': 'Watermark Brewing Company',
#   'phone': '2692810872',
#   'postal_code': '49127-1238',
#   'state': 'Michigan',
#   'street': '5781 Saint Joseph Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:40.161Z',
#   'website_url': 'http://www.watermarkbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'South Lyon',
#   'country': 'United States',
#   'id': 3762,
#   'latitude': '42.4554252170515',
#   'longitude': '-83.6509930768823',
#   'name': "Witch's Hat Brewing",
#   'phone': '2484862595',
#   'postal_code': '48178-1453',
#   'state': 'Michigan',
#   'street': '601 S Lafayette St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:41.305Z',
#   'website_url': 'http://www.witchshatbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Saint Paul',
#   'country': 'United States',
#   'id': 3785,
#   'latitude': '44.9510655128205',
#   'longitude': '-93.0880348205128',
#   'name': 'Barrel Theory Beer Company',
#   'phone': '6516003422',
#   'postal_code': '55101-2349',
#   'state': 'Minnesota',
#   'street': '248 7th St E',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:51.098Z',
#   'website_url': 'http://www.barreltheory.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Hibbing',
#   'country': 'United States',
#   'id': 3802,
#   'latitude': '47.4276931',
#   'longitude': '-92.9355964',
#   'name': 'BoomTown Brewery and Woodfire Grill',
#   'phone': '2184401710',
#   'postal_code': '55746-1713',
#   'state': 'Minnesota',
#   'street': '531 E Howard St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:44:58.216Z',
#   'website_url': 'http://www.boomtownwoodfire.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Duluth',
#   'country': 'United States',
#   'id': 3812,
#   'latitude': '46.7898679947981',
#   'longitude': '-92.0941880943814',
#   'name': 'Carmody Irish Pub & Brewing',
#   'phone': '2187404747',
#   'postal_code': '55802-2120',
#   'state': 'Minnesota',
#   'street': '308 E Superior St',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:00.853Z',
#   'website_url': 'http://www.carmodyirishpub.com'},
#  {'brewery_type': 'planning',
#   'city': None,
#   'country': 'United States',
#   'id': 584,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Falls Canyon Brewing Co.',
#   'phone': '',
#   'postal_code': None,
#   'state': None,
#   'street': '',
#   'tag_list': [],
#   'updated_at': '2018-07-24T01:32:55.260Z',
#   'website_url': ''},
#  {'brewery_type': 'micro',
#   'city': 'Scotia',
#   'country': 'United States',
#   'id': 561,
#   'latitude': None,
#   'longitude': None,
#   'name': 'Eel River Brewing Co - Facility and Warehouse',
#   'phone': '7077641772',
#   'postal_code': '95565',
#   'state': 'California',
#   'street': '600 K Bridge St',
#   'tag_list': [],
#   'updated_at': '2018-08-11T21:36:02.426Z',
#   'website_url': ''},
#  {'brewery_type': 'brewpub',
#   'city': 'Rochester',
#   'country': 'United States',
#   'id': 3832,
#   'latitude': '44.0293769630614',
#   'longitude': '-92.4786810104941',
#   'name': 'Forager Brewing Company',
#   'phone': '5072587490',
#   'postal_code': '55901-2741',
#   'state': 'Minnesota',
#   'street': '1005 6th St NW',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:10.895Z',
#   'website_url': 'http://www.foragerbrewery.com'},
#  {'brewery_type': 'micro',
#   'city': 'Nisswa',
#   'country': 'United States',
#   'id': 3850,
#   'latitude': '46.4983497833438',
#   'longitude': '-94.2976626608308',
#   'name': 'Gull Dam Brewing, Inc.',
#   'phone': '2189632739',
#   'postal_code': '56468',
#   'state': 'Minnesota',
#   'street': '23836 Smiley Rd',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:18.433Z',
#   'website_url': 'http://www.gulldambrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Lino Lakes',
#   'country': 'United States',
#   'id': 3852,
#   'latitude': '45.1890903',
#   'longitude': '-93.1064135',
#   'name': 'HammerHeart Brewing Company',
#   'phone': '6513482654',
#   'postal_code': '55014-1109',
#   'state': 'Minnesota',
#   'street': '7785 Lake Dr',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:19.341Z',
#   'website_url': 'http://www.hammerheartbrewing.com'},
#  {'brewery_type': 'micro',
#   'city': 'Minneapolis',
#   'country': 'United States',
#   'id': 3875,
#   'latitude': '44.9689387',
#   'longitude': '-93.2794629',
#   'name': 'Lakes & Legends Brewing Company',
#   'phone': '6129996020',
#   'postal_code': '55403-2316',
#   'state': 'Minnesota',
#   'street': '1368 Lasalle Ave',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:28.880Z',
#   'website_url': 'http://www.lakesandlegends.com'},
#  {'brewery_type': 'brewpub',
#   'city': 'Burnsville',
#   'country': 'United States',
#   'id': 3894,
#   'latitude': '44.7463634615385',
#   'longitude': '-93.3054737692308',
#   'name': 'Nutmeg Brewhouse',
#   'phone': '9528921438',
#   'postal_code': '55306-6211',
#   'state': 'Minnesota',
#   'street': '1905 County Road 42 W',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.098Z',
#   'website_url': 'http://www.nutmegbrewhouse.com'},
#  {'brewery_type': 'micro',
#   'city': 'Maple Grove',
#   'country': 'United States',
#   'id': 3896,
#   'latitude': '45.1260514285714',
#   'longitude': '-93.4258984285714',
#   'name': 'OMNI Brewing Company',
#   'phone': '7152229832',
#   'postal_code': '55369-3629',
#   'state': 'Minnesota',
#   'street': '9462 Deerwood Ln N',
#   'tag_list': [],
#   'updated_at': '2018-08-24T00:45:37.980Z',
#   'website_url': ''}]

# %%
brewer = pd.read_csv('breweries.csv')
moving_df.head(3)
# Out:
#                         id                     name brewery_type  \
# 0  siluria-brewing-company  Siluria Brewing Company     planning
# 1        cheaha-brewing-co        Cheaha Brewing Co      brewpub
# 2      avondale-brewing-co      Avondale Brewing Co        micro
#
#             street        city    state postal_code  \
# 0              NaN   Alabaster  Alabama  35007-8501
# 1  1208 Walnut Ave    Anniston  Alabama  36201-4526
# 2    201 41st St S  Birmingham  Alabama  35222-1932
#
#                            website_url         phone created_at updated_at  \
# 0        http://www.siluriabrewing.com  2.054828e+09    32:47.7    20:27.0
# 1  http://www.cheahabrewingcompany.com  2.567707e+09    32:47.4    20:08.8
# 2       http://www.avondalebrewing.com  2.057775e+09    32:47.3    19:57.8
#
#          country  longitude   latitude  tags
# 0  United States -86.816377  33.244281   NaN
# 1  United States -85.833774  33.660167   NaN
# 2  United States -86.774322  33.524521   NaN

# %%
# save the Geometry as feature
features = M_violations.apply(
    lambda row: Feature(geometry=Point((float(row['LONGITUDE']), float(row['LATITUDE'])))),
    axis=1).tolist()

# all the other columns used as properties
properties = M_violations.drop(['LONGITUDE', 'LATITUDE'], axis=1).to_dict('records')

# whole geojson object
feature_collection = FeatureCollection(features=features, properties=properties)
